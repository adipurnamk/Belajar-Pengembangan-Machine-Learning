# %% [markdown]
# <a href="https://colab.research.google.com/github/adipurnamk/Belajar-Pengembangan-Machine-Learning/blob/master/Time_Series_with_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Datasset](https://www.kaggle.com/sumanthvrao/daily-climate-time-series-data)

# %%
import numpy as np
import pandas as pd
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
import zipfile,os
local_zip = '/content/archive.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content')
zip_ref.close()

os.listdir('/content')
# Out:
# ['.config',
#  'archive.zip',
#  'DailyDelhiClimateTrain.csv',
#  'DailyDelhiClimateTest.csv',
#  'sample_data']

# %%
data_train = pd.read_csv('/content/DailyDelhiClimateTrain.csv')
data_train.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
data_train.isnull().sum()
# Out:
# date            0
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %%
dates = data_train['date'].values
temp  = data_train['meantemp'].values
 
 
plt.figure(figsize=(15,5))
plt.plot(dates, temp)
plt.title('Temperature average',
          fontsize=20);

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)

# %%
train_set = windowed_dataset(temp, window_size=60, batch_size=100, shuffle_buffer=1000)
model = tf.keras.models.Sequential([
  tf.keras.layers.LSTM(60, return_sequences=True),
  tf.keras.layers.LSTM(60),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
])

# %%
optimizer = tf.keras.optimizers.SGD(lr=1.0000e-04, momentum=0.9)
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
history = model.fit(train_set,epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Layer lstm is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 15/15 [==============================] - 1s 87ms/step - loss: 25.1505 - mae: 25.6505
# Epoch 2/100
# 15/15 [==============================] - 1s 92ms/step - loss: 25.0052 - mae: 25.5052
# Epoch 3/100
# 15/15 [==============================] - 1s 92ms/step - loss: 24.8268 - mae: 25.3268
# Epoch 4/100
# 15/15 [==============================] - 1s 92ms/step - loss: 24.6303 - mae: 25.1303
# Epoch 5/100
# 15/15 [==============================] - 1s 94ms/step - loss: 24.4188 - mae: 24.9188
# Epoch 6/100
# 15/15 [==============================] - 1s 94ms/step - loss: 24.1849 - mae: 24.6849
# Epoch 7/100
# 15/15 [==============================] - 1s 89ms/step - loss: 23.9103 - mae: 24.4103
# Epoch 8/100
# 15/15 [==============================] - 1s 90ms/step - loss: 23.5826 - mae: 24.0826
# Epoch 9/100
# 15/15 [==============================] - 1s 94ms/step - loss: 23.2043 - mae: 23.7043
# Epoch 10/100
# 15/15 [==============================] - 1s 90ms/step - loss: 22.7568 - mae: 23.2568
# Epoch 11/100
# 15/15 [==============================] - 1s 89ms/step - loss: 22.2143 - mae: 22.7143
# Epoch 12/100
# 15/15 [==============================] - 1s 96ms/step - loss: 21.5467 - mae: 22.0467
# Epoch 13/100
# 15/15 [==============================] - 1s 92ms/step - loss: 20.7098 - mae: 21.2098
# Epoch 14/100
# 15/15 [==============================] - 1s 92ms/step - loss: 19.6319 - mae: 20.1318
# Epoch 15/100
# 15/15 [==============================] - 1s 92ms/step - loss: 18.2098 - mae: 18.7097
# Epoch 16/100
# 15/15 [==============================] - 1s 95ms/step - loss: 16.2988 - mae: 16.7982
# Epoch 17/100
# 15/15 [==============================] - 1s 89ms/step - loss: 13.7167 - mae: 14.2110
# Epoch 18/100
# 15/15 [==============================] - 1s 94ms/step - loss: 10.5839 - mae: 11.0754
# Epoch 19/100
# 15/15 [==============================] - 1s 94ms/step - loss: 7.7311 - mae: 8.2213
# Epoch 20/100
# 15/15 [==============================] - 1s 91ms/step - loss: 5.9082 - mae: 6.3970
# Epoch 21/100
# 15/15 [==============================] - 1s 90ms/step - loss: 5.2715 - mae: 5.7589
# Epoch 22/100
# 15/15 [==============================] - 1s 91ms/step - loss: 5.1984 - mae: 5.6792
# Epoch 23/100
# 15/15 [==============================] - 1s 90ms/step - loss: 5.1515 - mae: 5.6335
# Epoch 24/100
# 15/15 [==============================] - 1s 92ms/step - loss: 5.0487 - mae: 5.5299
# Epoch 25/100
# 15/15 [==============================] - 1s 91ms/step - loss: 4.7103 - mae: 5.1910
# Epoch 26/100
# 15/15 [==============================] - 1s 92ms/step - loss: 4.1778 - mae: 4.6591
# Epoch 27/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.9966 - mae: 3.4656
# Epoch 28/100
# 15/15 [==============================] - 1s 92ms/step - loss: 2.3929 - mae: 2.8532
# Epoch 29/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.3078 - mae: 2.7666
# Epoch 30/100
# 15/15 [==============================] - 1s 92ms/step - loss: 2.2435 - mae: 2.7016
# Epoch 31/100
# 15/15 [==============================] - 1s 92ms/step - loss: 2.2903 - mae: 2.7485
# Epoch 32/100
# 15/15 [==============================] - 1s 91ms/step - loss: 3.3054 - mae: 3.7733
# Epoch 33/100
# 15/15 [==============================] - 1s 90ms/step - loss: 2.7141 - mae: 3.1768
# Epoch 34/100
# 15/15 [==============================] - 1s 90ms/step - loss: 2.6827 - mae: 3.1480
# Epoch 35/100
# 15/15 [==============================] - 1s 95ms/step - loss: 2.2962 - mae: 2.7540
# Epoch 36/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.2589 - mae: 2.7172
# Epoch 37/100
# 15/15 [==============================] - 1s 90ms/step - loss: 2.1771 - mae: 2.6352
# Epoch 38/100
# 15/15 [==============================] - 1s 98ms/step - loss: 2.1496 - mae: 2.6072
# Epoch 39/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.1088 - mae: 2.5664
# Epoch 40/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.0991 - mae: 2.5564
# Epoch 41/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.0837 - mae: 2.5409
# Epoch 42/100
# 15/15 [==============================] - 1s 98ms/step - loss: 2.0942 - mae: 2.5512
# Epoch 43/100
# 15/15 [==============================] - 1s 89ms/step - loss: 2.1660 - mae: 2.6234
# Epoch 44/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.0635 - mae: 2.5196
# Epoch 45/100
# 15/15 [==============================] - 1s 96ms/step - loss: 2.0979 - mae: 2.5550
# Epoch 46/100
# 15/15 [==============================] - 1s 90ms/step - loss: 2.0526 - mae: 2.5086
# Epoch 47/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.0528 - mae: 2.5099
# Epoch 48/100
# 15/15 [==============================] - 1s 90ms/step - loss: 2.0657 - mae: 2.5223
# Epoch 49/100
# 15/15 [==============================] - 1s 92ms/step - loss: 2.0372 - mae: 2.4932
# Epoch 50/100
# 15/15 [==============================] - 1s 89ms/step - loss: 2.0244 - mae: 2.4796
# Epoch 51/100
# 15/15 [==============================] - 1s 94ms/step - loss: 2.0181 - mae: 2.4734
# Epoch 52/100
# 15/15 [==============================] - 1s 92ms/step - loss: 2.0270 - mae: 2.4829
# Epoch 53/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.0151 - mae: 2.4703
# Epoch 54/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.0375 - mae: 2.4939
# Epoch 55/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.0185 - mae: 2.4741
# Epoch 56/100
# 15/15 [==============================] - 1s 95ms/step - loss: 2.0051 - mae: 2.4599
# Epoch 57/100
# 15/15 [==============================] - 1s 90ms/step - loss: 2.0074 - mae: 2.4623
# Epoch 58/100
# 15/15 [==============================] - 1s 92ms/step - loss: 2.0004 - mae: 2.4554
# Epoch 59/100
# 15/15 [==============================] - 1s 92ms/step - loss: 2.0026 - mae: 2.4573
# Epoch 60/100
# 15/15 [==============================] - 1s 90ms/step - loss: 2.0148 - mae: 2.4699
# Epoch 61/100
# 15/15 [==============================] - 1s 91ms/step - loss: 1.9981 - mae: 2.4533
# Epoch 62/100
# 15/15 [==============================] - 1s 95ms/step - loss: 2.0154 - mae: 2.4713
# Epoch 63/100
# 15/15 [==============================] - 1s 95ms/step - loss: 2.0026 - mae: 2.4574
# Epoch 64/100
# 15/15 [==============================] - 1s 100ms/step - loss: 1.9930 - mae: 2.4479
# Epoch 65/100
# 15/15 [==============================] - 1s 93ms/step - loss: 1.9889 - mae: 2.4434
# Epoch 66/100
# 15/15 [==============================] - 1s 98ms/step - loss: 2.0028 - mae: 2.4578
# Epoch 67/100
# 15/15 [==============================] - 1s 93ms/step - loss: 1.9979 - mae: 2.4529
# Epoch 68/100
# 15/15 [==============================] - 1s 90ms/step - loss: 1.9914 - mae: 2.4462
# Epoch 69/100
# 15/15 [==============================] - 1s 92ms/step - loss: 2.0033 - mae: 2.4591
# Epoch 70/100
# 15/15 [==============================] - 1s 93ms/step - loss: 1.9863 - mae: 2.4409
# Epoch 71/100
# 15/15 [==============================] - 1s 95ms/step - loss: 1.9976 - mae: 2.4529
# Epoch 72/100
# 15/15 [==============================] - 1s 93ms/step - loss: 2.0047 - mae: 2.4596
# Epoch 73/100
# 15/15 [==============================] - 1s 91ms/step - loss: 1.9915 - mae: 2.4464
# Epoch 74/100
# 15/15 [==============================] - 1s 91ms/step - loss: 2.0330 - mae: 2.4903
# Epoch 75/100
# 15/15 [==============================] - 1s 89ms/step - loss: 2.0121 - mae: 2.4672
# Epoch 76/100
# 15/15 [==============================] - 1s 92ms/step - loss: 2.0115 - mae: 2.4675
# Epoch 77/100
# 15/15 [==============================] - 1s 93ms/step - loss: 1.9871 - mae: 2.4425
# Epoch 78/100
# 15/15 [==============================] - 1s 91ms/step - loss: 1.9871 - mae: 2.4420
# Epoch 79/100
# 15/15 [==============================] - 1s 92ms/step - loss: 1.9783 - mae: 2.4332
# Epoch 80/100
# 15/15 [==============================] - 1s 91ms/step - loss: 1.9897 - mae: 2.4453
# Epoch 81/100
# 15/15 [==============================] - 1s 90ms/step - loss: 1.9799 - mae: 2.4347
# Epoch 82/100
# 15/15 [==============================] - 1s 90ms/step - loss: 1.9854 - mae: 2.4407
# Epoch 83/100
# 15/15 [==============================] - 1s 90ms/step - loss: 1.9815 - mae: 2.4366
# Epoch 84/100
# 15/15 [==============================] - 1s 97ms/step - loss: 1.9859 - mae: 2.4411
# Epoch 85/100
# 15/15 [==============================] - 1s 94ms/step - loss: 1.9878 - mae: 2.4432
# Epoch 86/100
# 15/15 [==============================] - 1s 94ms/step - loss: 1.9830 - mae: 2.4385
# Epoch 87/100
# 15/15 [==============================] - 1s 94ms/step - loss: 1.9772 - mae: 2.4320
# Epoch 88/100
# 15/15 [==============================] - 1s 90ms/step - loss: 2.0107 - mae: 2.4673
# Epoch 89/100
# 15/15 [==============================] - 1s 90ms/step - loss: 1.9923 - mae: 2.4486
# Epoch 90/100
# 15/15 [==============================] - 1s 92ms/step - loss: 1.9829 - mae: 2.4380
# Epoch 91/100
# 15/15 [==============================] - 1s 91ms/step - loss: 1.9785 - mae: 2.4335
# Epoch 92/100
# 15/15 [==============================] - 1s 95ms/step - loss: 1.9792 - mae: 2.4339
# Epoch 93/100
# 15/15 [==============================] - 1s 91ms/step - loss: 1.9761 - mae: 2.4311
# Epoch 94/100
# 15/15 [==============================] - 1s 91ms/step - loss: 1.9791 - mae: 2.4345
# Epoch 95/100
# 15/15 [==============================] - 1s 94ms/step - loss: 1.9732 - mae: 2.4285
# Epoch 96/100
# 15/15 [==============================] - 1s 91ms/step - loss: 1.9779 - mae: 2.4332
# Epoch 97/100
# 15/15 [==============================] - 1s 94ms/step - loss: 1.9752 - mae: 2.4303
# Epoch 98/100
# 15/15 [==============================] - 1s 94ms/step - loss: 1.9825 - mae: 2.4379
# Epoch 99/100
# 15/15 [==============================] - 1s 89ms/step - loss: 1.9731 - mae: 2.4280
# Epoch 100/100
# 15/15 [==============================] - 1s 93ms/step - loss: 1.9815 - mae: 2.4368
