# %% [markdown]
# <a href="https://colab.research.google.com/github/adipurnamk/Belajar-Pengembangan-Machine-Learning/blob/master/Multiclass_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# dataset [Kaggle](https://www.kaggle.com/uciml/iris)

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %%
# melakukan ekstraksi pada file zip
import zipfile,os
local_zip = '/content/19_420_bundle_archive.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content')
zip_ref.close()

os.listdir('/content')
# Out:
# ['.config',
#  'database.sqlite',
#  'Iris.csv',
#  '19_420_bundle_archive.zip',
#  'sample_data']

# %%
import pandas as pd
df = pd.read_csv('/content/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df = df.drop(columns='Id')

# %%
category = pd.get_dummies(df.Species)
category
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# 148            0                0               1
# 149            0                0               1
#
# [150 rows x 3 columns]

# %%
new_df = pd.concat([df, category], axis=1)
new_df = new_df.drop(columns='Species')
new_df
# Out:
#      SepalLengthCm  SepalWidthCm  ...  Iris-versicolor  Iris-virginica
# 0              5.1           3.5  ...                0               0
# 1              4.9           3.0  ...                0               0
# 2              4.7           3.2  ...                0               0
# 3              4.6           3.1  ...                0               0
# 4              5.0           3.6  ...                0               0
# ..             ...           ...  ...              ...             ...
# 145            6.7           3.0  ...                0               1
# 146            6.3           2.5  ...                0               1
# 147            6.5           3.0  ...                0               1
# 148            6.2           3.4  ...                0               1
# 149            5.9           3.0  ...                0               1
#
# [150 rows x 7 columns]

# %%
dataset = new_df.values
dataset
# Out:
# array([[5.1, 3.5, 1.4, ..., 1. , 0. , 0. ],
#        [4.9, 3. , 1.4, ..., 1. , 0. , 0. ],
#        [4.7, 3.2, 1.3, ..., 1. , 0. , 0. ],
#        ...,
#        [6.5, 3. , 5.2, ..., 0. , 0. , 1. ],
#        [6.2, 3.4, 5.4, ..., 0. , 0. , 1. ],
#        [5.9, 3. , 5.1, ..., 0. , 0. , 1. ]])

# %%
# Pilih 4 kolom pertama untuk dijadikan sebagai atribut
X = dataset[:,0:4]
# Pilih 3 kolom terakhir sebagai label
y = dataset[:,4:7]

# %%
# Normalize
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %%
# pisahkan data training dan testing
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, y, test_size=0.3)

# %%
# Activation function yang digunakan pada layer terakhir dipilih softmax karena activation tersebut umum dipakai untuk klasifikasi multi kelas

model = Sequential([    
                    Dense(64, activation='relu', input_shape=(4,)),    
                    Dense(64, activation='relu'),    
                    Dense(3, activation='softmax'),])

# %%
# Untuk masalah klasifikasi multi kelas, Anda dapat menggunakan loss ‘categorical_crossentropy

model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1144 - accuracy: 0.5810
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0878 - accuracy: 0.6952
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0654 - accuracy: 0.7048
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0463 - accuracy: 0.7048
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0265 - accuracy: 0.7048
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0070 - accuracy: 0.7048
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9868 - accuracy: 0.7048
# Epoch 8/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9638 - accuracy: 0.7048
# Epoch 9/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9380 - accuracy: 0.7048
# Epoch 10/100
# ...

# %%
model.evaluate(X_test, Y_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1058 - accuracy: 0.9778
# [0.10580813139677048, 0.9777777791023254]
