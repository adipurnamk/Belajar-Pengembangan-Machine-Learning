# %% [markdown]
# <a href="https://colab.research.google.com/github/adipurnamk/Belajar-Pengembangan-Machine-Learning/blob/master/MNIST_Dataset_from_Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
mnist = tf.keras.datasets.mnist

# %%
(gambar_latih, label_latih), (gambar_testing, label_testing) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
import numpy as np
np.set_printoptions(linewidth=200)
import matplotlib.pyplot as plt
plt.imshow(gambar_latih[0])
print(label_latih[0])
# Out:
# 5

# %%
# normalisasi, membagi nilai pixel dengan 255
gambar_latih  = gambar_latih / 255.0
gambar_testing = gambar_testing / 255.0

# %%
# Untuk layer pertama kita menggunakan layer khusus yaitu Flatten yang berfungsi untuk mengubah input kita yang berupa matriks 2 dimensi menjadi array 1 dimensi. 

model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)), 
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu), 
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

# %%
model.compile(optimizer = tf.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(gambar_latih, label_latih, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2621 - accuracy: 0.9260
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1128 - accuracy: 0.9671
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0777 - accuracy: 0.9769
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0560 - accuracy: 0.9832
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0433 - accuracy: 0.9866
